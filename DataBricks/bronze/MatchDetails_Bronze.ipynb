# %%
path = r'abfss://bronze-external@ipldatastorage.dfs.core.windows.net/Match_details/'
filename = r'335987_player_match.parquet'

# %%
df = spark.read.format('parquet').load(path+filename)

# %%
from pyspark.sql.functions import current_timestamp, lit

df = df.withColumn('insert_ts', current_timestamp())
df = df.withColumn('file_name', lit(filename))

# %%
df.display()

# %%
df.write.format('delta')\
  .mode('append')\
  .saveAsTable('ipl.bronze.match_details')
